# %%
import pandas as pd
file = 'article0.csv'
df0 = pd.read_csv(file)
df0#technology
# Out:
#         category                                              title  \
# 0     technology         From Clockworks to Computers on Our Wrists
# 1     technology               A Modest Privacy Protection Proposal
# 2     technology  If You Charge People to Tweet, They’ll Revolt ...
# 3     technology  Why You Shouldn’t Use Facebook to Log In to Ot...
# 4     technology                                  Raised by YouTube
# 5     technology  Why I Left My Big Fancy Tech Job and Wrote a Book
# 6     technology                                 The Big Disruption
# 7     technology                                Alexa, Blow My Mind
# 8     technology                           Uber’s Massive Data Play
# 9     technology                      Facebook Is Just Like the NSA
# 10    technology                      VR: Gimmick or Game Changing?
# 11    technology                       The Distraction-Free Android
# 12    technology  Even the Best AI for Spotting Fake News Is Sti...
# ...

# %%
file = 'article1.csv'
df1 = pd.read_csv(file)
df1#culture
# Out:
#      category                                              title  \
# 0     culture  Why We Need to Include Female Villains in Our ...
# 1     culture                            The Power of the F-Bomb
# 2     culture                          Naming the Unspoken Thing
# 3     culture  What My ’80s Childhood Taught Me About Rape Cu...
# 4     culture  Costumes, Consenticorns and the New Rules of N...
# 5     culture                       Why Chinese People Don’t Cry
# 6     culture                             We Won: Get Used to It
# 7     culture  Dear Christine Blasey Ford: I, Too, Was Sexual...
# 8     culture      The Sex Positive Parent’s Guide to Sexy Dolls
# 9     culture                           Two for the Price of One
# 10    culture  Here’s Why Nations Turn on Themselves: Insight...
# 11    culture                           Re-education In Our Time
# 12    culture      Why the Dark Side of the Force Had to Be Dark
# ...

# %%
file = 'article2.csv'
df2 = pd.read_csv(file)
df2#design
# Out:
#     category                                              title  \
# 0     design         From Clockworks to Computers on Our Wrists
# 1     design  When to Ask Forgiveness and Secretly Build a P...
# 2     design     How Bad Design Perpetuates Harmful Stereotypes
# 3     design                      A Decision Tree for Designers
# 4     design           Apple’s New iPhones Are Simply Excellent
# 5     design  Apple’s iPhone Event Signals a Design Inflecti...
# 6     design                        Design Won’t Save the World
# 7     design            Our Online Behavior is a Design Problem
# 8     design  Meet the Bay Area artist who illustrated the e...
# 9     design                      Push Notifications Are Broken
# 10    design                  Meet R3–14, My Personal Assistant
# 11    design  Data, AI, ML, IoT Becoming A New Medium Of Design
# 12    design              Copenhagen- The City of Fairtale Life
# 13    design  5 UX job ads that will help you hire great des...
# ...

# %%
file = 'article3.csv'
df3 = pd.read_csv(file)
df3#politics
# Out:
#       category                                              title  \
# 0     politics  We Found a Way to Increase Voter Turnout in Te...
# 1     politics  ‘Think of Your Sons’: What Parents Can Do Abou...
# 2     politics  Dear Journalists, Please Do Your Duty for Demo...
# 3     politics  Jamil Smith: Beyond Brett Kavanaugh’s Past, We...
# 4     politics  If You Charge People to Tweet, They’ll Revolt ...
# 5     politics                    This Is a Constitutional Crisis
# 6     politics                 How the Patriarchy Protects Itself
# 7     politics            Meet Mike Pence, the GOP’s Cash Machine
# 8     politics  Dear Christine Blasey Ford: I, Too, Was Sexual...
# 9     politics  Patterns of Abuse Echo Plainly in the Kavanaug...
# 10    politics                          People as Political Pawns
# 11    politics                    The Forgotten Reason to Vote No
# 12    politics                    Letters: The Left vs Liberalism
# ...

# %%
file = 'article4.csv'
df4 = pd.read_csv(file)
df4#entrepre
# Out:
#       category                                              title  \
# 0     entrepre  Wyatt Lindquist: Frisbee Enthusiast, Entrepreneur
# 1     entrepre  Shubham Banerjee: VC-Backed Entrepreneur, Opti...
# 2     entrepre   Andrew Yu: Computer Whiz, Entrepreneur, Musician
# 3     entrepre                  Letter to a Would-Be Entrepreneur
# 4     entrepre  The Demise of Blockbuster, and Other Failure F...
# 5     entrepre  Why a Leading Venture Capitalist Is Betting on...
# 6     entrepre   Crypto Nomads Seek “Proof of Nipple” in Thailand
# 7     entrepre          If Machiavelli Were Your Leadership Coach
# 8     entrepre                Silicon Valley’s Business of Giving
# 9     entrepre                    What Really Kills Most Startups
# 10    entrepre  3 Ways to Clarify Your Authentic Personal Bran...
# 11    entrepre  4 categories of metrics to help keep your comp...
# 12    entrepre  Growing Our SaaS Company To $1M+ ARR: 7 People...
# ...

# %%
file = 'article5.csv'
df5 = pd.read_csv(file)
df5#science
# Out:
#      category                                              title  \
# 0     science                        What’s So Scary About Momo?
# 1     science  Why Is Everybody Freaking Out About Sperm Counts?
# 2     science              What Exactly Is Cancer Immunotherapy?
# 3     science                Why You Can Never Eat Just One Oreo
# 4     science  A Journey to Siberia in Search of Woolly Mammoths
# 5     science                    Can You Biohack Your Fertility?
# 6     science  The Ultra-Pure, Super-Secret Sand That Makes Y...
# 7     science                       Your DNA Is Not Your Culture
# 8     science                  Drowning in the Fountain of Youth
# 9     science         If You Think You’re a Genius, You’re Crazy
# 10    science                                     Bias in the ER
# 11    science      Does Depression Have an Evolutionary Purpose?
# 12    science     What Quantum Gravity Needs Is More Experiments
# ...

# %%
file = 'article6.csv'
df6 = pd.read_csv(file)
df6#self
# Out:
#      category                                              title  \
# 0        self  How to Create Any Habit With Advice From the F...
# 1        self         It’s Not What You Know, It’s How You Think
# 2        self  You’re Always Interviewing, Whether You Realiz...
# 3        self  You Don’t Need a Breakthrough, You Need a Micr...
# 4        self          Your Parent Has Died. What Do You Do Now?
# 5        self         7 Lessons Millennials Taught Me About Work
# 6        self      I Was Scared Straight by Judge Judy’s Bailiff
# 7        self                                 Once Upon a Summer
# 8        self                                     Every 36 Years
# 9        self                           I Was Sure I’d Die Young
# 10       self                             How I Found Hope Again
# 11       self  The Ladder Theory: How to Tackle Life One Thin...
# 12       self                 Growing Up In Australia’s Backyard
# ...

# %%
file = 'article7.csv'
df7 = pd.read_csv(file)
df7#popular
# Out:
#      category                                              title  \
# 0     popular          A Guide for the Quest to the Unlived Life
# 1     popular                       The Problem That Has No Name
# 2     popular           Your Work Is the Only Thing That Matters
# 3     popular     Brett Kavanaugh and the Power of Public Trauma
# 4     popular                    How to Make Time to Make Things
# 5     popular  Relax, Ladies. Don’t Be So Uptight. You Know Y...
# 6     popular     The Coders Programming Themselves Out of a Job
# 7     popular                           How to Handle Lady Anger
# 8     popular                                   The 50/50 Murder
# 9     popular                          The End of Snap and Tesla
# 10    popular            How to Decide What to Do With Your Life
# 11    popular  Why We Are Self Publishing the Aviary Cookbook...
# 12    popular                 Blockchain Is a Semantic Wasteland
# ...

# %%
df = pd.concat([df0,df1,df2,df3,df4,df5,df6,df7],ignore_index=True)
df
# Out:
#          category                                              title  \
# 0      technology         From Clockworks to Computers on Our Wrists
# 1      technology               A Modest Privacy Protection Proposal
# 2      technology  If You Charge People to Tweet, They’ll Revolt ...
# 3      technology  Why You Shouldn’t Use Facebook to Log In to Ot...
# 4      technology                                  Raised by YouTube
# 5      technology  Why I Left My Big Fancy Tech Job and Wrote a Book
# 6      technology                                 The Big Disruption
# 7      technology                                Alexa, Blow My Mind
# 8      technology                           Uber’s Massive Data Play
# 9      technology                      Facebook Is Just Like the NSA
# 10     technology                      VR: Gimmick or Game Changing?
# 11     technology                       The Distraction-Free Android
# 12     technology  Even the Best AI for Spotting Fake News Is Sti...
# ...

# %%
df.to_csv('articles.csv',encoding='utf_8_sig')

# %%
category = ['technology','culture','design','politics','entrepre','science','self','popular','total','unrepeated_total']
count = [len(df0),len(df1),len(df2),len(df3),len(df4),len(df5),len(df6),len(df7),len(df),len(df['title'].value_counts())]
summary = pd.DataFrame([category,count])
summary
# Out:
#             0        1       2         3         4        5     6        7  \
# 0  technology  culture  design  politics  entrepre  science  self  popular
# 1        2694     2771     204      2217      1041     1276  2336     1659
#
#        8                 9
# 0  total  unrepeated_total
# 1  14198             12798
